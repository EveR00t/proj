# %%
import pandas as pd
import matplotlib.pyplot as plt

db = pd.read_csv('/content/drive/MyDrive/Project/trying.csv')

db.head()
# Out:
#    ID GosNumber    Model        Data
# 0   1  А221НУ83  Citroen  03/02/2024
# 1   2  В510ЕМ21  Hyundai  11/02/2024
# 2   3  К999ВН97     Ford  14/02/2024
# 3   4  С200СС23  Hyundai  16/02/2024
# 4   5  О007ВЕ01  Renault  23/02/2024

# %%
count=0
for i in db['Model']:
  if i =="Hyundai":
    count+=1
print(count)
# Out:
# 5

# %%
# Out:
#     ID GosNumber          Model        Data
# 0    1  А221НУ83        Citroen  03/02/2024
# 1    2  В510ЕМ21        Hyundai  11/02/2024
# 2    3  К999ВН97           Ford  14/02/2024
# 3    4  С200СС23        Hyundai  16/02/2024
# 4    5  О007ВЕ01        Renault  23/02/2024
# ..  ..       ...            ...         ...
# 72  73  К204НУ76         Suzuki  06/01/2011
# 73  74  Н306АЕ85  Mercedes-Benz  26/05/2005
# 74  75  М948ЕН90           Jeep  26/05/2004
# 75  76  К999ВН97           Ford  18/02/2011
# 76  77  М164ТС68          Tesla  20/10/2012
#
# [70 rows x 4 columns]
