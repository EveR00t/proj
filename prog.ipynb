# %%
# !git clone https://github.com/EveR00t/proj.git
# Out:
# fatal: destination path 'proj' already exists and is not an empty directory.

# %%
import pandas as pd
import matplotlib as plt

# %%
db = pd.read_csv('/content/proj/trying.csv')
db.head()
# Out:
#    ID GosNumber    Model        Data
# 0   1  А221НУ83  Citroen  03/02/2024
# 1   2  В510ЕМ21  Hyundai  11/02/2024
# 2   3  К999ВН97     Ford  14/02/2024
# 3   4  С200СС23  Hyundai  16/02/2024
# 4   5  О007ВЕ01  Renault  23/02/2024

# %%
count=0
for i in db['Model']:
  if i =="Hyundai":
    count+=1
print(count)
# Out:
# 5
